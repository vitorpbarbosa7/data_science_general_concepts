# %%
! pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.3-py3-none-any.whl (15.1 MB)
#      |████████████████████████████████| 15.1 MB 5.4 MB/s eta 0:00:01
# Collecting tqdm>=4.43.0
#   Downloading tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 8.2 MB/s  eta 0:00:01
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (1.3.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (5.2.2)
# Requirement already satisfied: numpy>=1.16.0 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (1.18.1)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (3.4.3)
# Requirement already satisfied: scipy>=1.3.2 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (1.4.1)
# Requirement already satisfied: jinja2>=2.11.1 in /home/vpb/anaconda3/lib/python3.7/site-packages (from sweetviz) (2.11.1)
# Requirement already satisfied: pytz>=2017.3 in /home/vpb/anaconda3/lib/python3.7/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/vpb/anaconda3/lib/python3.7/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2.8.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/vpb/anaconda3/lib/python3.7/site-packages (from importlib-resources>=1.2.0->sweetviz) (3.6.0)
# Requirement already satisfied: cycler>=0.10 in /home/vpb/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/vpb/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.3->sweetviz) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/vpb/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.3->sweetviz) (2.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/vpb/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.1.3->sweetviz) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/vpb/anaconda3/lib/python3.7/site-packages (from jinja2>=2.11.1->sweetviz) (1.1.1)
# Requirement already satisfied: six>=1.5 in /home/vpb/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (1.14.0)
# Requirement already satisfied: setuptools in /home/vpb/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.1.3->sweetviz) (45.2.0.post20200210)
# Installing collected packages: tqdm, sweetviz
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
# Successfully installed sweetviz-2.1.3 tqdm-4.62.3

# %%
import pandas as pd
import pandasql as ps
import sklearn

from sklearn.datasets import load_boston

from sklearn.datasets import fetch_openml
housing = fetch_openml(name="house_prices").data

housing
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         0.0      0.0   None   None
# 1            Lvl    AllPub  ...         0.0      0.0   None   None
# 2            Lvl    AllPub  ...         0.0      0.0   None   None
# 3            Lvl    AllPub  ...         0.0      0.0   None   None
# 4            Lvl    AllPub  ...         0.0      0.0   None   None
# ...          ...       ...  ...         ...      ...    ...    ...
# 1455         Lvl    AllPub  ...         0.0      0.0   None   None
# 1456         Lvl    AllPub  ...         0.0      0.0   None  MnPrv
# 1457         Lvl    AllPub  ...         0.0      0.0   None  GdPrv
# 1458         Lvl    AllPub  ...         0.0      0.0   None   None
# 1459         Lvl    AllPub  ...         0.0      0.0   None   None
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0           None     0.0    2.0  2008.0        WD         Normal
# 1           None     0.0    5.0  2007.0        WD         Normal
# 2           None     0.0    9.0  2008.0        WD         Normal
# 3           None     0.0    2.0  2006.0        WD        Abnorml
# 4           None     0.0   12.0  2008.0        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1455        None     0.0    8.0  2007.0        WD         Normal
# 1456        None     0.0    2.0  2010.0        WD         Normal
# 1457        Shed  2500.0    5.0  2010.0        WD         Normal
# 1458        None     0.0    4.0  2010.0        WD         Normal
# 1459        None     0.0    6.0  2008.0        WD         Normal
#
# [1460 rows x 80 columns]

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(housing)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
